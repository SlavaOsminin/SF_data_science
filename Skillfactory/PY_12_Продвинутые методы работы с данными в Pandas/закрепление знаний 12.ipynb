# %% [markdown]
# Для решения задач нам понадобится выделить из признака title год выпуска фильма. Для этого напишем функцию get_year_release(arg).

# %%
import pandas as pd

movies_rt_df = pd.read_csv('C:\DS\IDE\Skillfactory\Data\movies\datta3.csv')
ratings_movies = movies_rt_df.copy()
ratings_movies
# Out:
#         Unnamed: 0  userId  movieId  rating                 date
# 0                0       1        1     4.0  2000-07-30 18:45:03  \
# 1                1       1        3     4.0  2000-07-30 18:20:47
# 2                2       1        6     4.0  2000-07-30 18:37:04
# 3                3       1       47     5.0  2000-07-30 19:03:35
# 4                4       1       50     5.0  2000-07-30 18:48:51
# ...            ...     ...      ...     ...                  ...
# 100831      100831     610   166534     4.0  2017-05-03 21:53:22
# 100832      100832     610   168248     5.0  2017-05-03 22:21:31
# 100833      100833     610   168250     5.0  2017-05-08 19:50:47
# 100834      100834     610   168252     5.0  2017-05-03 21:19:12
# 100835      100835     610   170875     3.0  2017-05-03 21:20:15
#
#                                  title
# 0                     Toy Story (1995)  \
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# 3          Seven (a.k.a. Se7en) (1995)
# 4           Usual Suspects, The (1995)
# ...                                ...
# 100831                    Split (2017)
# 100832   John Wick: Chapter Two (2017)
# 100833                  Get Out (2017)
# 100834                    Logan (2017)
# 100835  The Fate of the Furious (2017)
#
#                                              genres
# 0       Adventure|Animation|Children|Comedy|Fantasy
# 1                                    Comedy|Romance
# 2                             Action|Crime|Thriller
# 3                                  Mystery|Thriller
# 4                            Crime|Mystery|Thriller
# ...                                             ...
# 100831                        Drama|Horror|Thriller
# 100832                        Action|Crime|Thriller
# 100833                                       Horror
# 100834                                Action|Sci-Fi
# 100835                  Action|Crime|Drama|Thriller
#
# [100836 rows x 7 columns]

# %%
#библиотека для регулярных выражений
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %% [markdown]
# Данная функция основана на регулярных выражениях и использует модуль ***re***, с которым мы пока не работали.
#
# → Модуль ***re*** предназначен для поиска шаблонов в тексте и встроен в язык, поэтому не нуждается в установке.

# %% [markdown]
# ## ДОПОЛНИТЕЛЬНО
#
# При желании вы можете ознакомиться с регулярными выражениями по ***[ссылке](https://tproger.ru/translations/regular-expression-python/)***, однако это не является обязательным для выполнения заданий в этом юните.

# %% [markdown]
# Из модуля ***re*** нам понадобится только функция ***findall()***, которая позволяет найти в строке все слова, удовлетворяющие шаблону. Мы находим в строке с названием фильма шаблон "(DDDD)" — четыре цифры, обёрнутых в скобки, что соответствует году выпуска фильма. Если такого шаблона не было найдено (год выпуска не указан), функция возвращает None (в таблице это будет помечено как пропуск).

# %% [markdown]
# ### Совет: для выполнения заданий используйте изученные в этом модуле методы.

# %% [markdown]
# # Задание 8.1
# ### Создайте в таблице новый признак year_release, который соответствует году выпуска фильма.
# ### У скольких фильмов не указан год их выпуска?

# %%
ratings_movies['year_release'] = ratings_movies['title'].apply(get_year_release)
ratings_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    100836 non-null  int64
#  1   userId        100836 non-null  int64
#  2   movieId       100836 non-null  int64
#  3   rating        100836 non-null  float64
#  4   date          100836 non-null  object
#  5   title         100836 non-null  object
#  6   genres        100836 non-null  object
#  7   year_release  100818 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 6.2+ MB

# %% [markdown]
# # Задание 8.2
# ### Какой фильм, выпущенный в 1999 году, получил наименьшую среднюю оценку зрителей?
# ### В качестве ответа запишите название этого фильма без указания года его выпуска.

# %%
mask = ratings_movies['year_release'] == 1999
ratings_movies[mask].groupby('title')['rating'].mean().sort_values()
# Out:
# title
# Bloodsport: The Dark Kumite (1999)            0.5
# Simon Sez (1999)                              1.0
# Chill Factor (1999)                           1.0
# Source, The (1999)                            1.0
# Trippin' (1999)                               1.0
#                                              ...
# Trailer Park Boys (1999)                      5.0
# Larry David: Curb Your Enthusiasm (1999)      5.0
# Sun Alley (Sonnenallee) (1999)                5.0
# George Carlin: You Are All Diseased (1999)    5.0
# Five Senses, The (1999)                       5.0
# Name: rating, Length: 261, dtype: float64

# %% [markdown]
# # Задание 8.3
# ### Какое сочетание жанров фильмов (genres), выпущенных в 2010 году, получило наименьшую среднюю оценку (rating)?
# ### Запишите сочетание так же, как оно указано в таблице (через разделитель |, без пробелов).

# %%
mask1 = ratings_movies['year_release'] == 2010
ratings_movies[mask1].groupby('genres')['rating'].mean().sort_values()
# Out:
# genres
# Action|Sci-Fi                        1.000000
# Action|Adventure|Horror              1.500000
# Action|Drama|Fantasy                 1.500000
# Crime|Romance                        1.500000
# Adventure|Comedy|Fantasy             1.833333
#                                        ...
# Crime                                4.750000
# Comedy|Musical                       5.000000
# Animation|Drama|Fantasy|Mystery      5.000000
# Adventure|Children|Comedy|Mystery    5.000000
# Animation|Children|Mystery           5.000000
# Name: rating, Length: 119, dtype: float64

# %% [markdown]
# # Задание 8.4
# ### Какой пользователь (userId) посмотрел наибольшее количество различных (уникальных) комбинаций жанров (genres) фильмов? В качестве ответа запишите идентификатор этого пользователя.

# %%
ratings_movies.groupby('userId')['genres'].nunique().sort_values(ascending=False)
# Out:
# userId
# 599    524
# 414    482
# 448    403
# 380    399
# 474    395
#       ...
# 578     15
# 12      15
# 85      13
# 214     13
# 245     13
# Name: genres, Length: 610, dtype: int64

# %% [markdown]
# # Задание 8.5
# ### Найдите пользователя, который выставил наименьшее количество оценок, но его средняя оценка фильмам наибольшая.
# ### В качестве ответа укажите идентификатор этого пользователя

# %%
ratings_movies.groupby('userId')['rating'].agg(
    ['count', 'mean']
).sort_values(['count', 'mean'], ascending=[True, False])
# Out:
#         count      mean
# userId
# 53         20  5.000000
# 595        20  4.200000
# 189        20  4.100000
# 569        20  4.000000
# 278        20  3.875000
# ...       ...       ...
# 274      1346  3.235884
# 448      1864  2.847371
# 474      2108  3.398956
# 599      2478  2.642050
# 414      2698  3.391957
#
# [610 rows x 2 columns]

# %% [markdown]
# # Задание 8.6
# ### Найдите сочетание жанров (genres) за 2018 году, которое имеет наибольший средний рейтинг (среднее по столбцу rating), и при этом число выставленных ему оценок (количество значений в столбце rating) больше 10.
# ### Запишите сочетание так же, как оно указано в таблице (через разделитель |, без пробелов).

# %%
mask = ratings_movies['year_release'] == 2018
grouped = ratings_movies[mask].groupby('genres')['rating'].agg(
    ['mean', 'count']
)
grouped[grouped['count']>10].sort_values(
    by='mean',
    ascending=False
)
# Out:
#                              mean  count
# genres
# Action|Adventure|Sci-Fi  3.928571     14
# Action|Comedy|Sci-Fi     3.875000     12

# %% [markdown]
# # Задание 8.7
# ### Добавьте в таблицу новый признак ***year_rating*** — год выставления оценки. Создайте сводную таблицу, которая иллюстрирует зависимость среднего рейтинга фильма от года выставления оценки и жанра. Выберите верные варианты ответа, исходя из построенной таблицы:

# %%
ratings_movies['date'] = pd.to_datetime(ratings_movies['date'])
ratings_movies['year_rating'] = ratings_movies['date'].dt.year
pivot = ratings_movies.pivot_table(
    index='year_rating',
    columns='genres',
    values='rating',
    aggfunc='mean'
)
display(pivot)
# Out:
# genres       (no genres listed)    Action  Action|Adventure
# year_rating
# 1996                        NaN  2.730769          3.454545  \
# 1997                        NaN  3.538462          4.150000
# 1998                        NaN       NaN          4.200000
# 1999                        NaN       NaN          4.000000
# 2000                        NaN  2.588235          3.738462
# 2001                        NaN  3.000000          3.500000
# 2002                        NaN  2.750000          4.304348
# 2003                        NaN  3.833333          3.277778
# 2004                        NaN  2.700000          4.136364
# 2005                        NaN  3.357143          3.413043
# 2006                        NaN  2.166667          4.090909
# 2007                        NaN  2.583333          3.666667
# 2008                        NaN  3.000000          3.656250
# 2009                        NaN       NaN          3.714286
# 2010                        NaN  3.500000          3.437500
# 2011                        NaN  4.500000          3.888889
# 2012                        NaN  2.625000          3.900000
# 2013                        NaN  2.500000          3.833333
# 2014                        NaN       NaN          3.875000
# 2015                   0.500000  3.100000          3.560976
# 2016                   3.500000  3.545455          3.722222
# 2017                   3.000000  2.637931          3.527778
# 2018                   3.676471  2.588235          3.397436
#
# genres       Action|Adventure|Animation  Action|Adventure|Animation|Children
# year_rating
# 1996                                NaN                                  NaN  \
# 1997                                NaN                                  NaN
# 1998                                NaN                                  NaN
# 1999                                NaN                                  NaN
# 2000                                NaN                                  NaN
# 2001                                NaN                                  NaN
# 2002                                NaN                                  NaN
# 2003                                NaN                                  NaN
# 2004                                NaN                                  NaN
# 2005                                NaN                                  NaN
# 2006                                NaN                                  NaN
# 2007                                NaN                                  NaN
# 2008                                NaN                                  NaN
# 2009                                NaN                                  NaN
# 2010                                NaN                                  NaN
# 2011                                NaN                                  NaN
# 2012                                NaN                             4.000000
# 2013                                NaN                             3.000000
# 2014                              3.000                             3.500000
# 2015                              3.800                             3.666667
# 2016                              3.750                             3.833333
# 2017                              3.375                             3.500000
# 2018                              3.650                             3.166667
#
# genres       Action|Adventure|Animation|Children|Comedy
# year_rating
# 1996                                                NaN  \
# 1997                                                NaN
# 1998                                                NaN
# 1999                                                NaN
# 2000                                                NaN
# 2001                                                NaN
# 2002                                                NaN
# 2003                                                NaN
# 2004                                           4.000000
# 2005                                           4.107143
# 2006                                           3.833333
# 2007                                           3.846154
# 2008                                           4.125000
# 2009                                           3.900000
# 2010                                           4.333333
# 2011                                           3.500000
# 2012                                           3.785714
# 2013                                           4.333333
# 2014                                           3.250000
# 2015                                           3.565217
# 2016                                           3.925000
# 2017                                           3.676471
# 2018                                           3.741935
#
# genres       Action|Adventure|Animation|Children|Comedy|Fantasy
# year_rating
# 1996                                                       NaN   \
# 1997                                                       NaN
# 1998                                                       NaN
# 1999                                                       NaN
# 2000                                                       NaN
# 2001                                                       NaN
# 2002                                                       NaN
# 2003                                                       NaN
# 2004                                                       NaN
# 2005                                                       NaN
# 2006                                                       NaN
# 2007                                                  3.000000
# 2008                                                  4.000000
# 2009                                                       NaN
# 2010                                                       NaN
# 2011                                                       NaN
# 2012                                                       NaN
# 2013                                                       NaN
# 2014                                                  3.833333
# 2015                                                  3.833333
# 2016                                                  3.388889
# 2017                                                  3.700000
# 2018                                                  4.142857
#
# genres       Action|Adventure|Animation|Children|Comedy|IMAX
# year_rating
# 1996                                                     NaN  \
# 1997                                                     NaN
# 1998                                                     NaN
# 1999                                                     NaN
# 2000                                                     NaN
# 2001                                                     NaN
# 2002                                                     NaN
# 2003                                                     NaN
# 2004                                                     NaN
# 2005                                                     NaN
# 2006                                                     NaN
# 2007                                                     NaN
# 2008                                                     NaN
# 2009                                                3.250000
# 2010                                                3.500000
# 2011                                                     NaN
# 2012                                                3.550000
# 2013                                                5.000000
# 2014                                                3.500000
# 2015                                                3.375000
# 2016                                                3.666667
# 2017                                                1.000000
# 2018                                                3.700000
#
# genres       Action|Adventure|Animation|Children|Comedy|Romance
# year_rating
# 1996                                                       NaN   \
# 1997                                                       NaN
# 1998                                                       NaN
# 1999                                                       NaN
# 2000                                                       NaN
# 2001                                                       NaN
# 2002                                                       NaN
# 2003                                                       NaN
# 2004                                                       NaN
# 2005                                                       NaN
# 2006                                                       NaN
# 2007                                                       NaN
# 2008                                                       NaN
# 2009                                                       NaN
# 2010                                                  3.000000
# 2011                                                       NaN
# 2012                                                  4.000000
# 2013                                                       NaN
# 2014                                                  4.000000
# 2015                                                  2.333333
# 2016                                                  1.000000
# 2017                                                  1.000000
# 2018                                                  2.500000
#
# genres       Action|Adventure|Animation|Children|Comedy|Sci-Fi  ...
# year_rating                                                     ...
# 1996                                                       NaN  ...  \
# 1997                                                       NaN  ...
# 1998                                                       NaN  ...
# 1999                                                       NaN  ...
# 2000                                                       NaN  ...
# 2001                                                       NaN  ...
# 2002                                                       NaN  ...
# 2003                                                       NaN  ...
# 2004                                                       NaN  ...
# 2005                                                       NaN  ...
# 2006                                                       3.0  ...
# 2007                                                       2.8  ...
# 2008                                                       3.5  ...
# 2009                                                       2.5  ...
# 2010                                                       NaN  ...
# 2011                                                       4.0  ...
# 2012                                                       NaN  ...
# 2013                                                       NaN  ...
# 2014                                                       NaN  ...
# 2015                                                       2.5  ...
# 2016                                                       4.0  ...
# 2017                                                       2.0  ...
# 2018                                                       4.0  ...
#
# genres       Romance|Thriller  Romance|War  Romance|Western    Sci-Fi
# year_rating
# 1996                      NaN          NaN              NaN       NaN  \
# 1997                      NaN          NaN              NaN       NaN
# 1998                      NaN          NaN              NaN       NaN
# 1999                    2.000          NaN              NaN       NaN
# 2000                    4.000          NaN              3.0  3.416667
# 2001                      NaN          NaN              3.0  2.500000
# 2002                    3.000          NaN              NaN  3.750000
# 2003                    3.375          2.5              NaN  2.333333
# 2004                    3.000          3.0              3.5  2.125000
# 2005                    2.000          NaN              NaN  3.000000
# 2006                      NaN          NaN              NaN  0.500000
# 2007                    1.500          NaN              2.5  3.375000
# 2008                      NaN          NaN              NaN  3.125000
# 2009                      NaN          NaN              NaN  2.000000
# 2010                      NaN          NaN              NaN  4.000000
# 2011                      NaN          NaN              NaN  3.500000
# 2012                    2.500          NaN              NaN  4.166667
# 2013                      NaN          NaN              NaN  1.500000
# 2014                      NaN          NaN              NaN  2.500000
# 2015                      NaN          NaN              NaN  2.900000
# 2016                    2.500          NaN              NaN  3.555556
# 2017                    3.000          NaN              NaN  3.864865
# 2018                      NaN          NaN              NaN  3.128571
#
# genres       Sci-Fi|IMAX  Sci-Fi|Thriller  Sci-Fi|Thriller|IMAX  Thriller
# year_rating
# 1996                 NaN         2.666667                   NaN  3.838095  \
# 1997                 NaN         3.400000                   NaN  3.923077
# 1998                 NaN              NaN                   NaN  3.800000
# 1999                 NaN         4.000000                   NaN  3.700000
# 2000                 NaN         2.142857                   NaN  3.087912
# 2001                 NaN         2.500000                   NaN  3.477273
# 2002                 NaN         3.600000                   NaN  3.583333
# 2003                 NaN         3.142857                   NaN  3.250000
# 2004                 NaN              NaN                   NaN  3.464286
# 2005                 NaN         2.750000                   NaN  3.411765
# 2006                 NaN         4.500000                   NaN  3.735294
# 2007                 NaN         2.833333                   NaN  3.421875
# 2008                 NaN         3.000000                   NaN  3.333333
# 2009                 NaN         4.000000                   NaN  2.964286
# 2010                 NaN         2.500000                   NaN  2.833333
# 2011                 NaN         1.833333              4.000000  3.625000
# 2012                 NaN         3.500000              3.666667  3.083333
# 2013                 NaN         3.833333              4.000000  3.666667
# 2014            5.000000              NaN              4.000000  4.000000
# 2015            4.071429         3.764706              4.000000  2.911765
# 2016            3.807692         3.916667              3.666667  3.432432
# 2017            4.264706         3.750000              2.500000  3.152174
# 2018            3.500000         3.562500                   NaN  3.296296
#
# genres       War   Western
# year_rating
# 1996         NaN  3.117647
# 1997         NaN  3.000000
# 1998         NaN       NaN
# 1999         4.5  4.000000
# 2000         3.0  4.058824
# 2001         3.0  3.111111
# 2002         3.5  3.000000
# 2003         3.0  4.000000
# 2004         3.0  3.800000
# 2005         NaN  4.500000
# 2006         NaN  3.625000
# 2007         NaN  3.000000
# 2008         NaN  4.000000
# 2009         4.0  3.375000
# 2010         NaN  3.666667
# 2011         NaN  4.000000
# 2012         NaN  4.100000
# 2013         NaN  4.000000
# 2014         NaN  4.000000
# 2015         NaN  3.900000
# 2016         NaN  3.958333
# 2017         NaN  2.933333
# 2018         NaN  3.611111
#
# [23 rows x 951 columns]

# %% [markdown]
# ***A*** **За весь период (с 1996 по 2018 год) сочетание жанров Action|Adventure ни разу не получало среднюю оценку ниже 3.**
#
# ***B*** Наилучшую оценку жанр Action|Adventure|Animation|Children|Comedy|IMAX получил в 2010 году.
#
# ***C*** **Среди сочетаний жанров, получивших наивысшую среднюю оценку в 2018 году, есть сочетание Animation|Children|Mystery.**
#
# ***D*** Для жанра Comedy прослеживается тенденция падения рейтинга с каждым годом (с 1996 по 2018).

# %%
product = pd.read_csv('C:\DS\IDE\Skillfactory\Data\movies\products.csv', sep = ';')
order = pd.read_csv('C:\DS\IDE\Skillfactory\Data\movies\orders.csv', sep = ',')

# %%
order.rename(columns=lambda name: name.replace('ID товара', 'Tovar'), inplace=True)
order
# Out:
#                                                  Дата создания;Order ID;ID Покупателя;Статус;Оплачен;Отменен;Отгружен;Tovar;Количество
# 09.11.2019 21:55:51;9;10;Принят                                  ожидается оплата;Нет;Нет;Нет;103;5
# 09.11.2019 15:05:57;8;9;Принят                                  ожидается оплата;Нет;Нет;Нет;86;100
# 09.11.2019 15:05:57;8;9;Принят                                  ожидается оплата;Нет;Нет;Нет;104;10
# 09.11.2019 12:50:07;7;8;Принят                                   ожидается оплата;Нет;Нет;Нет;104;7
# 09.11.2019 12:00:00;6;1;Принят                                   ожидается оплата;Нет;Нет;Нет;104;5
# 09.11.2019 12:00:00;6;1;Принят                                   ожидается оплата;Нет;Нет;Нет;103;5
# 08.11.2019 08:36:22;5;5;Отменён;Нет;Да;Нет;124;1                                                NaN
# 08.11.2019 08:36:22;4;9;Принят                                     ожидается оплата;Нет;Нет;Да;91;1
# 08.11.2019 08:36:22;3;8;Оплачен                             формируется к отправке;Да;Нет;Нет;103;3
# 08.11.2019 08:36:22;3;8;Оплачен                             формируется к отправке;Да;Нет;Нет;104;3
# 08.11.2019 08:36:21;2;7;Выполнен;Да;Нет;Да;74;1                                                 NaN
# 08.11.2019 08:36:21;2;7;Выполнен;Да;Нет;Да;53;1                                                 NaN
# 08.11.2019 08:36:21;2;7;Выполнен;Да;Нет;Да;137;1                                                NaN
# 08.11.2019 08:36:21;2;7;Выполнен;Да;Нет;Да;47;1                                                 NaN
# 08.11.2019 08:36:20;1;5;Оплачен                              формируется к отправке;Да;Нет;Нет;71;1
# 08.11.2019 08:36:20;1;5;Оплачен                              формируется к отправке;Да;Нет;Нет;86;1
# 08.11.2019 08:36:20;1;5;Оплачен                              формируется к отправке;Да;Нет;Нет;51;1
# 01.01.2001 00:00:00;0;1;Оплачен                             формируется к отправке;Да;Нет;Нет;666;1

# %%
sss = order.merge(
    product, 
    left_on = 'Tovar',
    right_on = 'Product_ID',
    how = 'left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sss = order.merge(
#       2     product,
#       3     left_on = 'Tovar',
#       4     right_on = 'Product_ID',
#       5     how = 'left')
#
# File c:\Users\Slava\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:9848, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9829 @Substitution("")
#    9830 @Appender(_merge_doc, indents=2)
#    9831 def merge(
#    (...)
#    9844     validate: str | None = None,
#    9845 ) -> DataFrame:
#    9846     from pandas.core.reshape.merge import merge
# -> 9848     return merge(
#    9849         self,
#    9850         right,
#    9851         how=how,
#    9852         on=on,
#    9853         left_on=left_on,
#    9854         right_on=right_on,
#    9855         left_index=left_index,
#    9856         right_index=right_index,
#    9857         sort=sort,
#    9858         suffixes=suffixes,
#    9859         copy=copy,
#    9860         indicator=indicator,
#    9861         validate=validate,
#    9862     )
#
# File c:\Users\Slava\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:144, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     127 @Substitution("\nleft : DataFrame or named Series")
#     128 @Appender(_merge_doc, indents=0)
#     129 def merge(
#    (...)
#     142     validate: str | None = None,
#     143 ) -> DataFrame:
# --> 144     op = _MergeOperation(
#     145         left,
#     146         right,
#     147         how=how,
#     148         on=on,
#     149         left_on=left_on,
#     150         right_on=right_on,
#     151         left_index=left_index,
#     152         right_index=right_index,
#     153         sort=sort,
#     154         suffixes=suffixes,
#     155         indicator=indicator,
#     156         validate=validate,
#     157     )
#     158     return op.get_result(copy=copy)
#
# File c:\Users\Slava\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:733, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     726 self._cross = cross_col
#     728 # note this function has side effects
#     729 (
#     730     self.left_join_keys,
#     731     self.right_join_keys,
#     732     self.join_names,
# --> 733 ) = self._get_merge_keys()
#     735 # validate the merge keys dtypes. We may need to coerce
#     736 # to avoid incompatible dtypes
#     737 self._maybe_coerce_merge_keys()
#
# File c:\Users\Slava\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:1209, in _MergeOperation._get_merge_keys(self)
#    1205 if lk is not None:
#    1206     # Then we're either Hashable or a wrong-length arraylike,
#    1207     #  the latter of which will raise
#    1208     lk = cast(Hashable, lk)
# -> 1209     left_keys.append(left._get_label_or_level_values(lk))
#    1210     join_names.append(lk)
#    1211 else:
#    1212     # work-around for merge_asof(left_index=True)
#
# File c:\Users\Slava\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:1778, in NDFrame._get_label_or_level_values(self, key, axis)
#    1776     values = self.axes[axis].get_level_values(key)._values
#    1777 else:
# -> 1778     raise KeyError(key)
#    1780 # Check for duplicates
#    1781 if values.ndim > 1:
#
# KeyError: 'Tovar'
